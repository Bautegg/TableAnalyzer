# %%
import json

# %%
Def __init__(this, json_config,...):
this.json_config = json_config

# %%
print(type({}))
print(type(json.dump({})))

json.loads()
# Out:
# <class 'dict'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 print(type({}))
# ----> 2 print(type(json.dump({fp})))
#       4 json.loads()
#
# NameError: name 'fp' is not defined
